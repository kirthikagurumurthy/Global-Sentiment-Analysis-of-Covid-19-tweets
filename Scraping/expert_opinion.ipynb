# %%
import json
import csv
import tweepy
import re
import nltk
from nltk.stem import WordNetLemmatizer
import pandas as pd
import GetOldTweets3 as got
from nltk.corpus import stopwords
stopwords = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()
import numpy as np

# %%
df1=pd.read_json("../../expert_opinion_json/capt_tweets.json")
df2=pd.read_json("../../expert_opinion_json/capt_tweets1.json")
df3=pd.read_json("../../expert_opinion_json/cmomaha_tweets.json")
df4=pd.read_json("../../expert_opinion_json/cmomaha_tweets1.json")
df5=pd.read_json("../../expert_opinion_json/covidnewsbymib_tweets.json")
df6=pd.read_json("../../expert_opinion_json/covidnewsbymib_tweets1.json")
df7=pd.read_json("../../expert_opinion_json/drharshvardhan_tweets.json")
df8=pd.read_json("../../expert_opinion_json/drharshvardhan_tweets1.json")
df9=pd.read_json("../../expert_opinion_json/icmr_tweets.json")
df10=pd.read_json("../../expert_opinion_json/icmr_tweets1.json")
df11=pd.read_json("../../expert_opinion_json/jai_tweets.json")
df12=pd.read_json("../../expert_opinion_json/jai_tweets1.json")
df13=pd.read_json("../../expert_opinion_json/mohfw_tweets.json")
df14=pd.read_json("../../expert_opinion_json/mohfw_tweets1.json")
df15=pd.read_json("../../expert_opinion_json/mybmc_tweets.json")
df16=pd.read_json("../../expert_opinion_json/mybmc_tweets1.json")
df17=pd.read_json("../../expert_opinion_json/mygov_tweets.json")
df18=pd.read_json("../../expert_opinion_json/mygov_tweets1.json")
df19=pd.read_json("../../expert_opinion_json/pib_tweets.json")
df20=pd.read_json("../../expert_opinion_json/pib_tweets1.json")
df21=pd.read_json("../../expert_opinion_json/pmo_tweets.json")
df22=pd.read_json("../../expert_opinion_json/pmo_tweets1.json")
df23=pd.read_json("../../expert_opinion_json/pramod_tweets.json")
df24=pd.read_json("../../expert_opinion_json/pramod_tweets1.json")
df25=pd.read_json("../../expert_opinion_json/soumya_tweets.json")
df26=pd.read_json("../../expert_opinion_json/soumya_tweets1.json")
df27=pd.read_json("../../expert_opinion_json/vijay_tweets.json")
df28=pd.read_json("../../expert_opinion_json/vijay_tweets1.json")

# %%
frames = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28]
tw_df = pd.concat(frames)
tw_df
# Out:
#     has_media                                           hashtags  \
# 0        True                             [IndiaFightsCoronapic]
# 1        True                    [CoronaVirus, 104, Coronavid19]
# 2        True                             [IndiaFightsCoronapic]
# 3        True                    [CoronaVirus, 104, Coronavid19]
# 0        True                                  [MissionFatehpic]
# 1       False                                          [Covid19]
# 2        True                                         [COVID_19]
# 3        True                                         [Covid_19]
# 4       False                                                 []
# 5        True                                          [Covid19]
# 6        True                                         [Covid_19]
# 7        True                                            [Covid]
# 8        True                                  [MissionFatehpic]
# ...

# %%
tweets_df = tw_df[['hashtags','timestamp','text','screen_name','likes','retweets']]

# %%
tweets_df = tweets_df.reset_index()

# %%
tweets_df
# Out:
#       index                                           hashtags  \
# 0         0                             [IndiaFightsCoronapic]
# 1         1                    [CoronaVirus, 104, Coronavid19]
# 2         2                             [IndiaFightsCoronapic]
# 3         3                    [CoronaVirus, 104, Coronavid19]
# 4         0                                  [MissionFatehpic]
# 5         1                                          [Covid19]
# 6         2                                         [COVID_19]
# 7         3                                         [Covid_19]
# 8         4                                                 []
# 9         5                                          [Covid19]
# 10        6                                         [Covid_19]
# 11        7                                            [Covid]
# 12        8                                  [MissionFatehpic]
# 13        9                                          [Covid19]
# ...

# %%
tweets_df=tweets_df.drop(['index'],axis=1)

# %%
tweets_df.to_csv('../Datasets/expert_opinion.csv')
