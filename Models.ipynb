# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder 
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv('Preprocessed_labelled_dataset.csv')

# %%
df=df.drop(columns="Unnamed: 0")
df
# Out:
#                                               Tweet_text  \
# 0      Georgia may need to dip deep in its reserve fu...
# 1      Vatican: Migrants Are the ‘True Victims’ of th...
# 2      Coronavirus outbreak: Trudeau praises "positiv...
# 3      NOOOOOOO! No corona virus vaccine has EVER bee...
# 4      #HESA is meeting via videoconference today at ...
# ...                                                  ...
# 22526  My 1 year old is obsessed with @TheRealFunyuns...
# 22527  #Covid19 Ramaphosa says we must find those who...
# 22528  This is the article you should read today. #CO...
# 22529  I thank @GovWike for extending the lockdown da...
# 22530  It’s what I have been saying! #level3lockdown ...
#
#                                             Text_cleaned  \
# 0      ['georgia', 'may', 'need', 'dip', 'deep', 'res...
# 1      ['vatican', 'migrants', 'true', 'victims', 'co...
# 2      ['coronavirus', 'outbreak', 'trudeau', 'praise...
# 3      ['noo', 'corona', 'virus', 'vaccine', 'ever', ...
# 4      ['hesa', 'meeting', 'via', 'videoconference', ...
# ...                                                  ...
# 22526  ['year', 'old', 'obsessed', 'therealfunyuns', ...
# 22527  ['covid', 'ramaphosa', 'says', 'must', 'find',...
# 22528  ['article', 'read', 'today', 'covid', 'homeles...
# 22529  ['thank', 'govwike', 'extending', 'lockdown', ...
# 22530  ['saying', 'levellockdown', 'ramaphosa', 'covid']
#
#                                          Text_lemmatized  \
# 0      ['georgia', 'may', 'need', 'dip', 'deep', 'res...
# 1      ['vatican', 'migrant', 'true', 'victim', 'coro...
# 2      ['coronavirus', 'outbreak', 'trudeau', 'praise...
# 3      ['noo', 'corona', 'virus', 'vaccine', 'ever', ...
# 4      ['hesa', 'meeting', 'via', 'videoconference', ...
# ...                                                  ...
# 22526  ['year', 'old', 'obsessed', 'therealfunyuns', ...
# 22527  ['covid', 'ramaphosa', 'say', 'must', 'find', ...
# 22528  ['article', 'read', 'today', 'covid', 'homeles...
# 22529  ['thank', 'govwike', 'extending', 'lockdown', ...
# 22530  ['saying', 'levellockdown', 'ramaphosa', 'covid']
#
#                                      Text_lemmatized_str  sentiment_score  \
# 0      georgia may need dip deep reserve fund balance...                0
# 1      vatican migrant true victim coronavirus pandemic                 0
# 2      coronavirus outbreak trudeau praise positive c...                1
# 3      noo corona virus vaccine ever safe kill need v...               -3
# 4      hesa meeting via videoconference today pm et w...               -1
# ...                                                  ...              ...
# 22526  year old obsessed therealfunyuns fritolay get ...                2
# 22527  covid ramaphosa say must find infected early p...               -2
# 22528          article read today covid homelessness nyc                0
# 22529  thank govwike extending lockdown date obioakpo...                1
# 22530               saying levellockdown ramaphosa covid                0
#
#           Label
# 0       Neutral
# 1       Neutral
# 2      Positive
# 3      Negative
# 4      Negative
# ...         ...
# 22526  Positive
# 22527  Negative
# 22528   Neutral
# 22529  Positive
# 22530   Neutral
#
# [22531 rows x 6 columns]

# %%
#Negative tweets are labelled 0 , neutral as 1 and positive as 2
#Label encoding of sentiment
le = LabelEncoder() 
df['Label']= le.fit_transform(df['Label'])
df
# Out:
#                                               Tweet_text  \
# 0      Georgia may need to dip deep in its reserve fu...
# 1      Vatican: Migrants Are the ‘True Victims’ of th...
# 2      Coronavirus outbreak: Trudeau praises "positiv...
# 3      NOOOOOOO! No corona virus vaccine has EVER bee...
# 4      #HESA is meeting via videoconference today at ...
# ...                                                  ...
# 22526  My 1 year old is obsessed with @TheRealFunyuns...
# 22527  #Covid19 Ramaphosa says we must find those who...
# 22528  This is the article you should read today. #CO...
# 22529  I thank @GovWike for extending the lockdown da...
# 22530  It’s what I have been saying! #level3lockdown ...
#
#                                             Text_cleaned  \
# 0      ['georgia', 'may', 'need', 'dip', 'deep', 'res...
# 1      ['vatican', 'migrants', 'true', 'victims', 'co...
# 2      ['coronavirus', 'outbreak', 'trudeau', 'praise...
# 3      ['noo', 'corona', 'virus', 'vaccine', 'ever', ...
# 4      ['hesa', 'meeting', 'via', 'videoconference', ...
# ...                                                  ...
# 22526  ['year', 'old', 'obsessed', 'therealfunyuns', ...
# 22527  ['covid', 'ramaphosa', 'says', 'must', 'find',...
# 22528  ['article', 'read', 'today', 'covid', 'homeles...
# 22529  ['thank', 'govwike', 'extending', 'lockdown', ...
# 22530  ['saying', 'levellockdown', 'ramaphosa', 'covid']
#
#                                          Text_lemmatized  \
# 0      ['georgia', 'may', 'need', 'dip', 'deep', 'res...
# 1      ['vatican', 'migrant', 'true', 'victim', 'coro...
# 2      ['coronavirus', 'outbreak', 'trudeau', 'praise...
# 3      ['noo', 'corona', 'virus', 'vaccine', 'ever', ...
# 4      ['hesa', 'meeting', 'via', 'videoconference', ...
# ...                                                  ...
# 22526  ['year', 'old', 'obsessed', 'therealfunyuns', ...
# 22527  ['covid', 'ramaphosa', 'say', 'must', 'find', ...
# 22528  ['article', 'read', 'today', 'covid', 'homeles...
# 22529  ['thank', 'govwike', 'extending', 'lockdown', ...
# 22530  ['saying', 'levellockdown', 'ramaphosa', 'covid']
#
#                                      Text_lemmatized_str  sentiment_score  \
# 0      georgia may need dip deep reserve fund balance...                0
# 1      vatican migrant true victim coronavirus pandemic                 0
# 2      coronavirus outbreak trudeau praise positive c...                1
# 3      noo corona virus vaccine ever safe kill need v...               -3
# 4      hesa meeting via videoconference today pm et w...               -1
# ...                                                  ...              ...
# 22526  year old obsessed therealfunyuns fritolay get ...                2
# 22527  covid ramaphosa say must find infected early p...               -2
# 22528          article read today covid homelessness nyc                0
# 22529  thank govwike extending lockdown date obioakpo...                1
# 22530               saying levellockdown ramaphosa covid                0
#
#        Label
# 0          1
# 1          1
# 2          2
# 3          0
# 4          0
# ...      ...
# 22526      2
# 22527      0
# 22528      1
# 22529      2
# 22530      1
#
# [22531 rows x 6 columns]

# %%
#Train-test split
x_train, x_test, y_train, y_test = train_test_split(df['Text_lemmatized'], df['Label'], test_size=0.3, random_state=42)

# %%
#Model:Multinomial Naive Bayes
nb = Pipeline([('vect', CountVectorizer()),
               ('tfidf', TfidfTransformer()),
               ('clf', MultinomialNB()),
              ])
nb.fit(x_train, y_train)

from sklearn.metrics import classification_report
y_pred = nb.predict(x_test)

print('accuracy %s' % accuracy_score(y_pred, y_test))
print(classification_report(y_test, y_pred))
# Out:
# accuracy 0.6430473372781065
#               precision    recall  f1-score   support
#
#            0       0.61      0.89      0.72      2556
#            1       0.60      0.52      0.56      2336
#            2       0.86      0.45      0.59      1868
#
#     accuracy                           0.64      6760
#    macro avg       0.69      0.62      0.63      6760
# weighted avg       0.67      0.64      0.63      6760

# %%
#Model : Linear SVM

sgd = Pipeline([('vect', CountVectorizer()),
                ('tfidf', TfidfTransformer()),
                ('clf', SGDClassifier(loss='hinge', penalty='l2', random_state=42, max_iter=10, tol=None)),
               ])
sgd.fit(x_train, y_train)

y_pred = sgd.predict(x_test)

print('accuracy %s' % accuracy_score(y_pred, y_test))
print(classification_report(y_test, y_pred))
# Out:
# accuracy 0.7770710059171597
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.83      2556
#            1       0.72      0.68      0.70      2336
#            2       0.78      0.81      0.80      1868
#
#     accuracy                           0.78      6760
#    macro avg       0.77      0.78      0.78      6760
# weighted avg       0.78      0.78      0.78      6760

# %%
#Model: Logistic Regression

logreg = Pipeline([('vect', CountVectorizer()),
                ('tfidf', TfidfTransformer()),
                ('clf', LogisticRegression(n_jobs=1, C=1e5, max_iter=1500)),
               ])
logreg.fit(x_train, y_train)

y_pred = logreg.predict(x_test)

print('accuracy %s' % accuracy_score(y_pred, y_test))
print(classification_report(y_test, y_pred))
# Out:
# accuracy 0.7789940828402366
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.83      2556
#            1       0.69      0.72      0.70      2336
#            2       0.81      0.79      0.80      1868
#
#     accuracy                           0.78      6760
#    macro avg       0.78      0.78      0.78      6760
# weighted avg       0.78      0.78      0.78      6760

# %%
#Model: Decision Tree
DT = Pipeline([('vect', CountVectorizer()),
                ('tfidf', TfidfTransformer()),
                ('clf',  DecisionTreeClassifier(criterion="entropy")),
               ])

# Train Decision Tree Classifer
DT.fit(x_train,y_train)

#Predict the response for test dataset
y_pred = DT.predict(x_test)

print('accuracy %s' % accuracy_score(y_pred, y_test))
print(classification_report(y_test, y_pred))
# Out:
# accuracy 0.6326923076923077
#               precision    recall  f1-score   support
#
#            0       0.69      0.63      0.66      2556
#            1       0.57      0.64      0.60      2336
#            2       0.64      0.62      0.63      1868
#
#     accuracy                           0.63      6760
#    macro avg       0.64      0.63      0.63      6760
# weighted avg       0.64      0.63      0.63      6760

# %%
#Model Random forest
Rf = Pipeline([('vect', CountVectorizer()),
                ('tfidf', TfidfTransformer()),
                ('clf',  RandomForestClassifier()),
               ])

Rf.fit(x_train,y_train)

y_pred = Rf.predict(x_test)

print('accuracy %s' % accuracy_score(y_pred, y_test))
print(classification_report(y_test, y_pred))
# Out:
# accuracy 0.7423076923076923
#               precision    recall  f1-score   support
#
#            0       0.79      0.78      0.78      2556
#            1       0.67      0.73      0.70      2336
#            2       0.79      0.70      0.75      1868
#
#     accuracy                           0.74      6760
#    macro avg       0.75      0.74      0.74      6760
# weighted avg       0.75      0.74      0.74      6760
