# %%
import nltk
from nltk.tokenize import treebank
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer 
import math
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import random
from nltk.corpus import opinion_lexicon
from nltk.corpus import wordnet as wn
from nltk.stem import WordNetLemmatizer

# %%
positive = pd.read_csv("../Datasets/Classified_Country_tweets/Positive.csv")
neutral = pd.read_csv("../Datasets/Classified_Country_tweets/Neutral.csv")
negative = pd.read_csv("../Datasets/Classified_Country_tweets/Negative.csv")

# %%
frames = [positive,neutral,negative]
all_frames = pd.concat(frames)

# %%
all_frames
# Out:
#        Unnamed: 0                                             Tweets  \
# 0               0  I wish quick recovery for talented @TOLOnews J...
# 1               1  These chinese people on campus are so consider...
# 2               2  China’s Leader, Under Fire, Says He Led Corona...
# 3               3  RT @DarrenEuronews: Top 5 countries 🌍 with hig...
# 4               4  RT @MileyCyrus: Spain, you united in solidarit...
# ...           ...                                                ...
# 30500       30500  RT @YourAnonNews: Yesterday, there were 140,92...
# 30501       30501  RT @iloharare: In the face of #covid19, we run...
# 30502       30502  RT @SAfridiOfficial: I’ve been feeling unwell ...
# 30503       30503  It must be this Gvt which is worse than corona...
# 30504       30504  BREAKING: Deputy leader of Iran's parliament s...
#
#                                  Date      Country
# 0           2020-04-29 23:33:40+00:00  afghanistan
# ...

# %%
def vaderSentiment(value):
    if value >= 0.2:
        return("positive")
    
    elif value < -0.2:
        return("negative") 
    
    else : 
        return("Neutral")

# %%
def vaderSentimentValue(review):
    sid_obj =  SentimentIntensityAnalyzer()
    
    sentiment_dict = sid_obj.polarity_scores(str(review))
    
    return sentiment_dict['compound']

# %%
all_frames['Vader-sentiment value'] = all_frames['Tweets'].apply(vaderSentimentValue)
all_frames['Vader-sentiment'] = all_frames['Vader-sentiment value'].apply(vaderSentiment)

# %%
all_frames
# Out:
#        Unnamed: 0                                             Tweets  \
# 0               0  I wish quick recovery for talented @TOLOnews J...
# 1               1  These chinese people on campus are so consider...
# 2               2  China’s Leader, Under Fire, Says He Led Corona...
# 3               3  RT @DarrenEuronews: Top 5 countries 🌍 with hig...
# 4               4  RT @MileyCyrus: Spain, you united in solidarit...
# ...           ...                                                ...
# 30500       30500  RT @YourAnonNews: Yesterday, there were 140,92...
# 30501       30501  RT @iloharare: In the face of #covid19, we run...
# 30502       30502  RT @SAfridiOfficial: I’ve been feeling unwell ...
# 30503       30503  It must be this Gvt which is worse than corona...
# 30504       30504  BREAKING: Deputy leader of Iran's parliament s...
#
#                                  Date      Country  Vader-sentiment value  \
# ...

# %%
positive
# Out:
#        Unnamed: 0                                             Tweets  \
# 0               0  I wish quick recovery for talented @TOLOnews J...
# 1               1  These chinese people on campus are so consider...
# 2               2  China’s Leader, Under Fire, Says He Led Corona...
# 3               3  RT @DarrenEuronews: Top 5 countries 🌍 with hig...
# 4               4  RT @MileyCyrus: Spain, you united in solidarit...
# ...           ...                                                ...
# 33918       33918  RT @zambezi40: Gogo Project, #Mbare #Zimbabwe ...
# 33919       33919  RT @thenanobel: Thank you, @Olimex. Any kind o...
# 33920       33920  RT @chidodc: We are doing something really ins...
# 33921       33921  RT @communitypodium: Update #Covid19 #Zimbabwe...
# 33922       33922  RT @superone1950: 5 positive #COVID19 \nIn #Salem
#
#                                  Date      Country
# 0           2020-04-29 23:33:40+00:00  afghanistan
# ...

# %%
all_frames.to_csv("../Datasets/vader_dataset/vaderDataset.csv")
